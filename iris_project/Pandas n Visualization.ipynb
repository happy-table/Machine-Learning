# %% [markdown]
# # Q1.Open a jupiter notebook and import "pandas ,NumPy ,matplotlib ,seaborn and Sklean".

# %%
# ans
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
from sklearn.linear_model import LinearRegression

# %% [markdown]
# # Q2.Load the inbuilt iris dataset.

# %%
# ans
import pandas as pd
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
iris = pd.read_csv("IRIS.csv")
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # Q3.Peek into this data using head() ,info() and glance over some statistics using describe().

# %%
# ans
import pandas as pd
import seaborn as sns
df = sns.load_dataset("iris")
print(iris.head(4))
print(iris.tail(4))
print(iris.info())
print(iris.describe())
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
#      sepal_length  sepal_width  petal_length  petal_width         species
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
# ...

# %% [markdown]
# # Q4.Plot the distribution of all numerical features and the categorical target using matplotlib and observe the plots.

# %%
# ans
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Load dataset
df = sns.load_dataset("iris")

# Plot distribution of numerical features
df.hist(figsize=(6, 4), edgecolor='black')
plt.suptitle("Distribution of Numerical Features", fontsize=14)
plt.tight_layout()
plt.show()

# Plot categorical target (species) count
df['species'].value_counts().plot(kind='bar', color='skyblue', edgecolor='black')
plt.title("Count of Each Iris Species")
plt.xlabel("Species")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# # Q5.Plot a "featurepair-wise" scatter plot to see how the numerical features are correlated to each other and print out pair-wise correlation coefficients between the numerical features .

# %% [raw]
# This is known ad EDA(eexploratory data analysis) and it is recommended for any good data scientist to explore data thoroughly before moving on ro training /modelling phase.

# %%
# ans
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load dataset
df = pd.read_csv('iris.csv')

# Select only numeric columns
numeric_df = df.select_dtypes(include='number')

# 1. Pairwise scatter plot
sns.pairplot(numeric_df)
plt.show()

# Correlation matrix
correlation_matrix = numeric_df.corr()
print("Pairwise Correlation Coefficients:")
print(correlation_matrix)
# Out:
# Pairwise Correlation Coefficients:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.109369      0.871754     0.817954
# sepal_width      -0.109369     1.000000     -0.420516    -0.356544
# petal_length      0.871754    -0.420516      1.000000     0.962757
# petal_width       0.817954    -0.356544      0.962757     1.000000
